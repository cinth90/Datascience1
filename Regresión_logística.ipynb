# %% [markdown]
# <a href="https://colab.research.google.com/github/cinth90/Datascience1/blob/main/Regresi%C3%B3n_log%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Configuracion del entorno

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import  train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# #Creacion de un dataset simulado

# %%
data ={
    'Edad':[22,25,47,52,46,56,48,32,25,38],
    'Salario':[15000,29000,70000,80000,54000,81000,58000,360000,21000,590000],
    'Compro':[0,0,1,1,1,1,1,0,0,1]
}
df=pd.DataFrame(data)
df.head()
# Out:
#    Edad  Salario  Compro
# 0    22    15000       0
# 1    25    29000       0
# 2    47    70000       1
# 3    52    80000       1
# 4    46    54000       1

# %% [markdown]
# #Conjunto de entrenamiento y prueba

# %%
x = df[['Edad','Salario']]
y = df['Compro']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=0)

# %% [markdown]
# #Entrenamiento del modelo

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #Predicciones sobre el conjunto de prueba

# %%
y_pred = model.predict(x_test)

# %%
print("Accuracy", accuracy_score(y_test, y_pred))
print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))
print("Classification Report: \n", classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# Confusion Matrix:
#  [[1 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %% [markdown]
# #Visualizacion de predicciones

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test['Edad'], y_test, color= 'red', label= 'Valores reales')
plt.scatter(x_test['Edad'], y_pred, color= 'blue', label= 'Predicciones')
plt.xlabel('Edad')
plt.ylabel('Compro')
plt.legend(loc='upper left')
plt.title('Predicciones del modelo')
plt.show()

# %% [markdown]
# #Ejemplo mejorado con chatgpt
# Mejoras que hice:
#
# alpha: para hacer los puntos semi-transparentes y poder ver si se superponen.
#
# s: para agrandar los puntos y que se note mejor.
#
# edgecolors: para que los puntos reales tengan un borde negro y sean más distinguibles.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Graficar
plt.figure(figsize=(8,5))
plt.scatter(x_test['Edad'], y_test, color='red', label='Valores reales', alpha=0.7, s=80, edgecolors='black')
plt.scatter(x_test['Edad'], y_pred, color='blue', label='Predicciones', alpha=0.4, s=80)
plt.xlabel('Edad')
plt.ylabel('Compro')
plt.legend(loc='upper left')
plt.title('Predicciones del modelo')
plt.show()

# Métricas
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion Matrix:
#  [[1 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
